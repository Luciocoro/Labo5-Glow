# %%
import pyvisa as visa
import numpy as np
import time
import matplotlib.pyplot as plt
#import instrumental
import pandas as pd
import logging

# %%
rm = visa.ResourceManager()
print(rm.list_resources())
# Out:
# ('ASRL1::INSTR', 'ASRL2::INSTR', 'ASRL3::INSTR', 'ASRL10::INSTR', 'GPIB0::22::INSTR', 'GPIB0::23::INSTR')

# %%
#inicializo los instrumentos 

amperimetro = rm.open_resource('GPIB0::22::INSTR') 
volt = rm.open_resource("GPIB0::23::INSTR") 
pirani = rm.open_resource("ASRL3::INSTR", read_termination='\r')

# %%
print(amperimetro.query("MEASURE:VOLTAGE:DC?"))
print(volt.query("MEASURE:VOLTAGE:DC?"))
print((pirani.query("?GA1")))
# Out:
# -1.82100000E-06
#
# +2.42690000E-05
#
# 9.91E-02

# %%
amperimetro.write('SENS:ZERO:AUTO OFF')
volt.write('SENS:ZERO:AUTO OFF')

amperimetro.write('SENS:VOLT:DC:NPLC 0.02')
volt.write('SENS:VOLT:DC:NPLC 0.02')

# amperimetro.write('CONF:VOLT:DC 100,0.0001') #Seteamos el rango de voltajes que va a medir y los digitos usados - El de arriba ADR 22
volt.write('CONF:VOLT:DC 1,0.00001') #Seteamos el rango de voltajes que va a medir y los digitos usados - El de abajo
amperimetro.write('SENS:VOLT:DC:RANG:AUTO ON')
#volt.write('SENS:VOLT:DC:RANG:AUTO ON')
# Out:
# 27

# %% [markdown]
# MEDICION SIN PLOT

# %%
nro_medicion = 65

V_gen = 1.8 #V
Distancia = 4 #resta[cm]
cant_mediciones = 200
periodo = 30 #s
pendiente_rampa = 50 #%

T = [] #de aca sascamos para el V de la descarga en Volts
V_c = [] #de aca sale para la corriente en Volts
P = []
R2 = 55340
R1 = 67109000 #ohm
R3 = 14800

tiempo_entre_medicion = 0.3 #seg/medicion

mediciones_para_un_periodo_y_medio = periodo//tiempo_entre_medicion #Usamos // para obtener un numero entero de la división


#LOOP DE TOMA DE DATOS
for i in range(cant_mediciones):
    t_0 = time.time()
    #print(f'Medicion numero: {i}')
    t_voltimetro_i = time.time()    #Toma el tiempo para calcular cuánto tarda en medir
    T_i = float(volt.query("READ?")) 
    t_voltimetro_f = time.time()    #La medida al final del voltímetro es la misma que la inicial del amperimetro. Comparten variable
    V_ci = float(amperimetro.query("READ?"))
    t_amperimetro_f = time.time()   #Idem amperimetro
    P_i = float(pirani.query("?GA1"))
    t_pirani_f = time.time()

    P.append(P_i)
    T.append(T_i)
    V_c.append(V_ci)

    I=[]#esta es la del tubo
    for j in range(len(T)):
        I.append(float(V_c[j])/R3)
    I_1=[] 
    for j in range(len(T)):
        I_1.append(float(T[j])/R2)
    V=[]
    for j in range(len(V_c)):
        V.append(float(T[j])-float(V_c[j])+float(I_1[j])*R1)

    t_f = time.time()
    print(f'La medición del voltímetro tardó {t_voltimetro_f-t_voltimetro_i} segundos')
    print(f'La medición del amperímetro tardó {t_amperimetro_f - t_voltimetro_f} segundos')
    print(f'La medición del sensor pirani tardó {t_pirani_f - t_amperimetro_f} segundos')
    print(f'La medición tomo un total de {float(t_f) - float(t_0)} segundos')
    # time.sleep(tiempo_entre_medicion)

#GUARDADO DE DATOS
df = pd.DataFrame()
df["T"] = T #Tension en R2
df['V'] = V #Tension en celda
df["V_c"] = V_c  #Tension en R3
df['I'] = I #Corriente en celda
df["P"] = P
df['V_gen'] = pd.Series(V_gen, index = [0])
df['Distancia'] = pd.Series(Distancia, index = [0])
df['Mediciones p/s'] = pd.Series(tiempo_entre_medicion,index = [0])
df['Fecha'] = pd.Series([time.ctime()],index = [0])
df['Periodo'] = pd.Series(periodo, index = [0])
df['pendiente_rampa'] = pd.Series(pendiente_rampa, index = [0])

df.to_csv(f"C:/Users/publico/Desktop/G6L5V/Clase 18-10/Medición nro {nro_medicion}.csv", encoding = "utf-8")
# Out:
# La medición del voltímetro tardó 0.016859054565429688 segundos
# La medición del amperímetro tardó 0.05031275749206543 segundos
# La medición del sensor pirani tardó 0.11854910850524902 segundos
# La medición tomo un total de 0.18572092056274414 segundos
# La medición del voltímetro tardó 0.01669907569885254 segundos
# La medición del amperímetro tardó 0.014581441879272461 segundos
# La medición del sensor pirani tardó 0.2840392589569092 segundos
# La medición tomo un total de 0.3153197765350342 segundos
# La medición del voltímetro tardó 0.016761302947998047 segundos
# La medición del amperímetro tardó 0.019461870193481445 segundos
# La medición del sensor pirani tardó 0.28306102752685547 segundos
# La medición tomo un total de 0.31928420066833496 segundos
# La medición del voltímetro tardó 0.016247034072875977 segundos
# La medición del amperímetro tardó 0.015845060348510742 segundos
# La medición del sensor pirani tardó 0.29230737686157227 segundos
# La medición tomo un total de 0.324399471282959 segundos
# La medición del voltímetro tardó 0.009818553924560547 segundos
# La medición del amperímetro tardó 0.01390528678894043 segundos
# La medición del sensor pirani tardó 0.2932729721069336 segundos
# La medición tomo un total de 0.31699681282043457 segundos
# La medición del voltímetro tardó 0.01993274688720703 segundos
# La medición del amperímetro tardó 0.013428211212158203 segundos
# La medición del sensor pirani tardó 0.2907578945159912 segundos
# La medición tomo un total de 0.32411885261535645 segundos
# La medición del voltímetro tardó 0.017114639282226562 segundos
# La medición del amperímetro tardó 0.010238409042358398 segundos
# La medición del sensor pirani tardó 0.2894294261932373 segundos
# La medición tomo un total de 0.31678247451782227 segundos
# La medición del voltímetro tardó 0.016772747039794922 segundos
# La medición del amperímetro tardó 0.016674280166625977 segundos
# La medición del sensor pirani tardó 0.2837541103363037 segundos
# La medición tomo un total de 0.3172011375427246 segundos
# La medición del voltímetro tardó 0.01661229133605957 segundos
# La medición del amperímetro tardó 0.01661992073059082 segundos
# La medición del sensor pirani tardó 0.28357887268066406 segundos
# La medición tomo un total de 0.31681108474731445 segundos
# La medición del voltímetro tardó 0.01680445671081543 segundos
# La medición del amperímetro tardó 0.006607770919799805 segundos
# La medición del sensor pirani tardó 0.2937138080596924 segundos
# La medición tomo un total de 0.3171260356903076 segundos
# La medición del voltímetro tardó 0.016282081604003906 segundos
# La medición del amperímetro tardó 0.017090320587158203 segundos
# La medición del sensor pirani tardó 0.28969359397888184 segundos
# La medición tomo un total de 0.32306599617004395 segundos
# La medición del voltímetro tardó 0.01665210723876953 segundos
# La medición del amperímetro tardó 0.010546445846557617 segundos
# La medición del sensor pirani tardó 0.2902262210845947 segundos
# La medición tomo un total de 0.3174247741699219 segundos
# La medición del voltímetro tardó 0.016688108444213867 segundos
# La medición del amperímetro tardó 0.01663827896118164 segundos
# La medición del sensor pirani tardó 0.2837247848510742 segundos
# La medición tomo un total de 0.3170511722564697 segundos
# La medición del voltímetro tardó 0.016666173934936523 segundos
# La medición del amperímetro tardó 0.019448041915893555 segundos
# La medición del sensor pirani tardó 0.2807774543762207 segundos
# La medición tomo un total de 0.3168916702270508 segundos
# La medición del voltímetro tardó 0.0167233943939209 segundos
# La medición del amperímetro tardó 0.01939225196838379 segundos
# La medición del sensor pirani tardó 0.2909269332885742 segundos
# La medición tomo un total de 0.3270425796508789 segundos
# La medición del voltímetro tardó 0.016722917556762695 segundos
# La medición del amperímetro tardó 0.009249448776245117 segundos
# La medición del sensor pirani tardó 0.29116296768188477 segundos
# La medición tomo un total de 0.3171353340148926 segundos
# La medición del voltímetro tardó 0.016595840454101562 segundos
# La medición del amperímetro tardó 0.00932621955871582 segundos
# La medición del sensor pirani tardó 0.29749560356140137 segundos
# La medición tomo un total de 0.32341766357421875 segundos
# La medición del voltímetro tardó 0.018286705017089844 segundos
# La medición del amperímetro tardó 0.011283397674560547 segundos
# La medición del sensor pirani tardó 0.287492036819458 segundos
# La medición tomo un total de 0.3170621395111084 segundos
# La medición del voltímetro tardó 0.019349336624145508 segundos
# La medición del amperímetro tardó 0.014025211334228516 segundos
# La medición del sensor pirani tardó 0.2863020896911621 segundos
# La medición tomo un total de 0.31967663764953613 segundos
# La medición del voltímetro tardó 0.014004230499267578 segundos
# La medición del amperímetro tardó 0.016605615615844727 segundos
# La medición del sensor pirani tardó 0.2863306999206543 segundos
# La medición tomo un total de 0.3169405460357666 segundos
# La medición del voltímetro tardó 0.024144887924194336 segundos
# La medición del amperímetro tardó 0.006533145904541016 segundos
# La medición del sensor pirani tardó 0.2963430881500244 segundos
# La medición tomo un total de 0.32702112197875977 segundos
# La medición del voltímetro tardó 0.01409459114074707 segundos
# La medición del amperímetro tardó 0.017563819885253906 segundos
# La medición del sensor pirani tardó 0.28924083709716797 segundos
# La medición tomo un total de 0.32089924812316895 segundos
# La medición del voltímetro tardó 0.016755342483520508 segundos
# La medición del amperímetro tardó 0.010158538818359375 segundos
# La medición del sensor pirani tardó 0.29274606704711914 segundos
# La medición tomo un total de 0.319659948348999 segundos
# La medición del voltímetro tardó 0.014024019241333008 segundos
# La medición del amperímetro tardó 0.016717195510864258 segundos
# La medición del sensor pirani tardó 0.2863731384277344 segundos
# La medición tomo un total de 0.31711435317993164 segundos
# La medición del voltímetro tardó 0.013948678970336914 segundos
# La medición del amperímetro tardó 0.01662588119506836 segundos
# La medición del sensor pirani tardó 0.28621697425842285 segundos
# La medición tomo un total de 0.3167915344238281 segundos
# La medición del voltímetro tardó 0.023633718490600586 segundos
# La medición del amperímetro tardó 0.050668954849243164 segundos
# La medición del sensor pirani tardó 0.2498307228088379 segundos
# La medición tomo un total de 0.32413339614868164 segundos
# La medición del voltímetro tardó 0.01707315444946289 segundos
# La medición del amperímetro tardó 0.007682085037231445 segundos
# La medición del sensor pirani tardó 0.2920715808868408 segundos
# La medición tomo un total de 0.31682682037353516 segundos
# La medición del voltímetro tardó 0.017602205276489258 segundos
# La medición del amperímetro tardó 0.016299009323120117 segundos
# La medición del sensor pirani tardó 0.29027485847473145 segundos
# La medición tomo un total de 0.3241760730743408 segundos
# La medición del voltímetro tardó 0.016680240631103516 segundos
# La medición del amperímetro tardó 0.016094207763671875 segundos
# La medición del sensor pirani tardó 0.2840895652770996 segundos
# La medición tomo un total de 0.316864013671875 segundos
# La medición del voltímetro tardó 0.0167081356048584 segundos
# La medición del amperímetro tardó 0.016597270965576172 segundos
# La medición del sensor pirani tardó 0.28369593620300293 segundos
# La medición tomo un total de 0.3170013427734375 segundos
# La medición del voltímetro tardó 0.01668262481689453 segundos
# La medición del amperímetro tardó 0.016665935516357422 segundos
# La medición del sensor pirani tardó 0.29367828369140625 segundos
# La medición tomo un total de 0.3270268440246582 segundos
# La medición del voltímetro tardó 0.016696929931640625 segundos
# La medición del amperímetro tardó 0.006596565246582031 segundos
# La medición del sensor pirani tardó 0.29360437393188477 segundos
# La medición tomo un total de 0.3168978691101074 segundos
# La medición del voltímetro tardó 0.016776084899902344 segundos
# La medición del amperímetro tardó 0.009455442428588867 segundos
# La medición del sensor pirani tardó 0.2979872226715088 segundos
# La medición tomo un total de 0.32421875 segundos
# La medición del voltímetro tardó 0.016727924346923828 segundos
# La medición del amperímetro tardó 0.011199951171875 segundos
# La medición del sensor pirani tardó 0.288546085357666 segundos
# La medición tomo un total de 0.31647396087646484 segundos
# La medición del voltímetro tardó 0.019339323043823242 segundos
# La medición del amperímetro tardó 0.013983726501464844 segundos
# La medición del sensor pirani tardó 0.28359127044677734 segundos
# La medición tomo un total de 0.31691431999206543 segundos
# La medición del voltímetro tardó 0.0192873477935791 segundos
# La medición del amperímetro tardó 0.014157772064208984 segundos
# La medición del sensor pirani tardó 0.2861168384552002 segundos
# La medición tomo un total de 0.3195619583129883 segundos
# La medición del voltímetro tardó 0.015485048294067383 segundos
# La medición del amperímetro tardó 0.02319622039794922 segundos
# La medición del sensor pirani tardó 0.2857964038848877 segundos
# La medición tomo un total de 0.3244776725769043 segundos
# La medición del voltímetro tardó 0.019171953201293945 segundos
# La medición del amperímetro tardó 0.013596296310424805 segundos
# La medición del sensor pirani tardó 0.29021573066711426 segundos
# La medición tomo un total de 0.322983980178833 segundos
# La medición del voltímetro tardó 0.016805648803710938 segundos
# La medición del amperímetro tardó 0.010171890258789062 segundos
# La medición del sensor pirani tardó 0.29064106941223145 segundos
# La medición tomo un total de 0.31761860847473145 segundos
# La medición del voltímetro tardó 0.01666545867919922 segundos
# La medición del amperímetro tardó 0.01666426658630371 segundos
# La medición del sensor pirani tardó 0.2835988998413086 segundos
# La medición tomo un total de 0.3169286251068115 segundos
# La medición del voltímetro tardó 0.01665329933166504 segundos
# La medición del amperímetro tardó 0.016666889190673828 segundos
# La medición del sensor pirani tardó 0.2836580276489258 segundos
# La medición tomo un total de 0.31697821617126465 segundos
# La medición del voltímetro tardó 0.01665043830871582 segundos
# La medición del amperímetro tardó 0.019349098205566406 segundos
# La medición del sensor pirani tardó 0.29111790657043457 segundos
# La medición tomo un total de 0.3271174430847168 segundos
# La medición del voltímetro tardó 0.018320798873901367 segundos
# La medición del amperímetro tardó 0.007515907287597656 segundos
# La medición del sensor pirani tardó 0.2953827381134033 segundos
# La medición tomo un total de 0.32121944427490234 segundos
# La medición del voltímetro tardó 0.011857986450195312 segundos
# La medición del amperímetro tardó 0.009825944900512695 segundos
# La medición del sensor pirani tardó 0.2983107566833496 segundos
# La medición tomo un total de 0.3199946880340576 segundos
# La medición del voltímetro tardó 0.015967845916748047 segundos
# La medición del amperímetro tardó 0.010140180587768555 segundos
# La medición del sensor pirani tardó 0.2901744842529297 segundos
# La medición tomo un total de 0.3162825107574463 segundos
# La medición del voltímetro tardó 0.0193023681640625 segundos
# La medición del amperímetro tardó 0.014058351516723633 segundos
# La medición del sensor pirani tardó 0.28359556198120117 segundos
# La medición tomo un total de 0.3169562816619873 segundos
# La medición del voltímetro tardó 0.019358396530151367 segundos
# La medición del amperímetro tardó 0.014055967330932617 segundos
# La medición del sensor pirani tardó 0.2861909866333008 segundos
# La medición tomo un total de 0.31960535049438477 segundos
# La medición del voltímetro tardó 0.02405405044555664 segundos
# La medición del amperímetro tardó 0.014383077621459961 segundos
# La medición del sensor pirani tardó 0.28769493103027344 segundos
# La medición tomo un total de 0.32613205909729004 segundos
# La medición del voltímetro tardó 0.01837468147277832 segundos
# La medición del amperímetro tardó 0.013257026672363281 segundos
# La medición del sensor pirani tardó 0.2898087501525879 segundos
# La medición tomo un total de 0.3214404582977295 segundos
# La medición del voltímetro tardó 0.016610383987426758 segundos
# La medición del amperímetro tardó 0.012190103530883789 segundos
# La medición del sensor pirani tardó 0.2906529903411865 segundos
# La medición tomo un total de 0.31945347785949707 segundos
# La medición del voltímetro tardó 0.01717829704284668 segundos
# La medición del amperímetro tardó 0.014745235443115234 segundos
# La medición del sensor pirani tardó 0.2877810001373291 segundos
# La medición tomo un total de 0.319704532623291 segundos
# La medición del voltímetro tardó 0.017482519149780273 segundos
# La medición del amperímetro tardó 0.014795780181884766 segundos
# La medición del sensor pirani tardó 0.28002476692199707 segundos
# La medición tomo un total de 0.3123030662536621 segundos
# La medición del voltímetro tardó 0.01673436164855957 segundos
# La medición del amperímetro tardó 0.016576290130615234 segundos
# La medición del sensor pirani tardó 0.28706979751586914 segundos
# La medición tomo un total de 0.32038044929504395 segundos
# La medición del voltímetro tardó 0.016755342483520508 segundos
# La medición del amperímetro tardó 0.014982461929321289 segundos
# La medición del sensor pirani tardó 0.2920510768890381 segundos
# La medición tomo un total de 0.3237888813018799 segundos
# La medición del voltímetro tardó 0.017208576202392578 segundos
# La medición del amperímetro tardó 0.01849198341369629 segundos
# La medición del sensor pirani tardó 0.2877004146575928 segundos
# La medición tomo un total de 0.32340097427368164 segundos
# La medición del voltímetro tardó 0.016646385192871094 segundos
# La medición del amperímetro tardó 0.010093450546264648 segundos
# La medición del sensor pirani tardó 0.2902946472167969 segundos
# La medición tomo un total de 0.3170344829559326 segundos
# La medición del voltímetro tardó 0.016707658767700195 segundos
# La medición del amperímetro tardó 0.01667475700378418 segundos
# La medición del sensor pirani tardó 0.2835245132446289 segundos
# La medición tomo un total de 0.3169069290161133 segundos
# La medición del voltímetro tardó 0.016812562942504883 segundos
# La medición del amperímetro tardó 0.01988840103149414 segundos
# La medición del sensor pirani tardó 0.2908780574798584 segundos
# La medición tomo un total de 0.3275790214538574 segundos
# La medición del voltímetro tardó 0.01705336570739746 segundos
# La medición del amperímetro tardó 0.009050846099853516 segundos
# La medición del sensor pirani tardó 0.29037928581237793 segundos
# La medición tomo un total de 0.3164834976196289 segundos
# La medición del voltímetro tardó 0.016696929931640625 segundos
# La medición del amperímetro tardó 0.00989675521850586 segundos
# La medición del sensor pirani tardó 0.2971065044403076 segundos
# La medición tomo un total de 0.3237001895904541 segundos
# La medición del voltímetro tardó 0.016116857528686523 segundos
# La medición del amperímetro tardó 0.01430368423461914 segundos
# La medición del sensor pirani tardó 0.28951287269592285 segundos
# La medición tomo un total de 0.3199334144592285 segundos
# La medición del voltímetro tardó 0.013631105422973633 segundos
# La medición del amperímetro tardó 0.016889333724975586 segundos
# La medición del sensor pirani tardó 0.286700963973999 segundos
# La medición tomo un total de 0.31722140312194824 segundos
# La medición del voltímetro tardó 0.01341867446899414 segundos
# La medición del amperímetro tardó 0.016720056533813477 segundos
# La medición del sensor pirani tardó 0.28696155548095703 segundos
# La medición tomo un total de 0.31710028648376465 segundos
# La medición del voltímetro tardó 0.02290511131286621 segundos
# La medición del amperímetro tardó 0.007126331329345703 segundos
# La medición del sensor pirani tardó 0.28694653511047363 segundos
# La medición tomo un total de 0.31697797775268555 segundos
# La medición del voltímetro tardó 0.023029804229736328 segundos
# La medición del amperímetro tardó 0.016922950744628906 segundos
# La medición del sensor pirani tardó 0.28702473640441895 segundos
# La medición tomo un total de 0.3269774913787842 segundos
# La medición del voltímetro tardó 0.019448041915893555 segundos
# La medición del amperímetro tardó 0.01056361198425293 segundos
# La medición del sensor pirani tardó 0.29021382331848145 segundos
# La medición tomo un total de 0.32022547721862793 segundos
# La medición del voltímetro tardó 0.016753435134887695 segundos
# La medición del amperímetro tardó 0.016611337661743164 segundos
# La medición del sensor pirani tardó 0.28362202644348145 segundos
# La medición tomo un total de 0.3169867992401123 segundos
# La medición del voltímetro tardó 0.016723155975341797 segundos
# La medición del amperímetro tardó 0.016818523406982422 segundos
# La medición del sensor pirani tardó 0.2833893299102783 segundos
# La medición tomo un total de 0.31693100929260254 segundos
# La medición del voltímetro tardó 0.016777515411376953 segundos
# La medición del amperímetro tardó 0.016672134399414062 segundos
# La medición del sensor pirani tardó 0.29367828369140625 segundos
# La medición tomo un total de 0.32712793350219727 segundos
# La medición del voltímetro tardó 0.01669001579284668 segundos
# La medición del amperímetro tardó 0.016657590866088867 segundos
# La medición del sensor pirani tardó 0.28316736221313477 segundos
# La medición tomo un total de 0.3165149688720703 segundos
# La medición del voltímetro tardó 0.01675581932067871 segundos
# La medición del amperímetro tardó 0.016712188720703125 segundos
# La medición del sensor pirani tardó 0.29065752029418945 segundos
# La medición tomo un total de 0.3241255283355713 segundos
# La medición del voltímetro tardó 0.0165863037109375 segundos
# La medición del amperímetro tardó 0.01624584197998047 segundos
# La medición del sensor pirani tardó 0.28411149978637695 segundos
# La medición tomo un total de 0.3169436454772949 segundos
# La medición del voltímetro tardó 0.016700029373168945 segundos
# La medición del amperímetro tardó 0.016560792922973633 segundos
# La medición del sensor pirani tardó 0.28368210792541504 segundos
# La medición tomo un total de 0.3169429302215576 segundos
# La medición del voltímetro tardó 0.01679849624633789 segundos
# La medición del amperímetro tardó 0.020025968551635742 segundos
# La medición del sensor pirani tardó 0.28977489471435547 segundos
# La medición tomo un total de 0.3265993595123291 segundos
# La medición del voltímetro tardó 0.010428905487060547 segundos
# La medición del amperímetro tardó 0.013350725173950195 segundos
# La medición del sensor pirani tardó 0.2866847515106201 segundos
# La medición tomo un total de 0.31046438217163086 segundos
# La medición del voltímetro tardó 0.013643503189086914 segundos
# La medición del amperímetro tardó 0.016663312911987305 segundos
# La medición del sensor pirani tardó 0.28969287872314453 segundos
# La medición tomo un total de 0.31999969482421875 segundos
# La medición del voltímetro tardó 0.016686677932739258 segundos
# La medición del amperímetro tardó 0.010534286499023438 segundos
# La medición del sensor pirani tardó 0.29026222229003906 segundos
# La medición tomo un total de 0.31748318672180176 segundos
# La medición del voltímetro tardó 0.016739845275878906 segundos
# La medición del amperímetro tardó 0.016709089279174805 segundos
# La medición del sensor pirani tardó 0.2835540771484375 segundos
# La medición tomo un total de 0.3170030117034912 segundos
# La medición del voltímetro tardó 0.01667308807373047 segundos
# La medición del amperímetro tardó 0.01668405532836914 segundos
# La medición del sensor pirani tardó 0.2835581302642822 segundos
# La medición tomo un total de 0.31691527366638184 segundos
# La medición del voltímetro tardó 0.01671910285949707 segundos
# La medición del amperímetro tardó 0.01667952537536621 segundos
# La medición del sensor pirani tardó 0.2937180995941162 segundos
# La medición tomo un total de 0.3271167278289795 segundos
# La medición del voltímetro tardó 0.016684770584106445 segundos
# La medición del amperímetro tardó 0.0162351131439209 segundos
# La medición del sensor pirani tardó 0.2840282917022705 segundos
# La medición tomo un total de 0.31694817543029785 segundos
# La medición del voltímetro tardó 0.016600847244262695 segundos
# La medición del amperímetro tardó 0.01675271987915039 segundos
# La medición del sensor pirani tardó 0.29018235206604004 segundos
# La medición tomo un total de 0.3235359191894531 segundos
# La medición del voltímetro tardó 0.016702890396118164 segundos
# La medición del amperímetro tardó 0.010096549987792969 segundos
# La medición del sensor pirani tardó 0.2903401851654053 segundos
# La medición tomo un total de 0.3171396255493164 segundos
# La medición del voltímetro tardó 0.019997596740722656 segundos
# La medición del amperímetro tardó 0.01321554183959961 segundos
# La medición del sensor pirani tardó 0.28359079360961914 segundos
# La medición tomo un total de 0.3168039321899414 segundos
# La medición del voltímetro tardó 0.02014017105102539 segundos
# La medición del amperímetro tardó 0.013312101364135742 segundos
# La medición del sensor pirani tardó 0.286975622177124 segundos
# La medición tomo un total de 0.32042789459228516 segundos
# La medición del voltímetro tardó 0.02292490005493164 segundos
# La medición del amperímetro tardó 0.00712132453918457 segundos
# La medición del sensor pirani tardó 0.29643678665161133 segundos
# La medición tomo un total de 0.32648301124572754 segundos
# La medición del voltímetro tardó 0.013358354568481445 segundos
# La medición del amperímetro tardó 0.016763687133789062 segundos
# La medición del sensor pirani tardó 0.29068875312805176 segundos
# La medición tomo un total de 0.32081079483032227 segundos
# La medición del voltímetro tardó 0.016653776168823242 segundos
# La medición del amperímetro tardó 0.009600400924682617 segundos
# La medición del sensor pirani tardó 0.29077982902526855 segundos
# La medición tomo un total de 0.3170340061187744 segundos
# La medición del voltímetro tardó 0.016640901565551758 segundos
# La medición del amperímetro tardó 0.01660299301147461 segundos
# La medición del sensor pirani tardó 0.2836785316467285 segundos
# La medición tomo un total de 0.3169224262237549 segundos
# La medición del voltímetro tardó 0.016613245010375977 segundos
# La medición del amperímetro tardó 0.01671004295349121 segundos
# La medición del sensor pirani tardó 0.2835705280303955 segundos
# La medición tomo un total de 0.3168938159942627 segundos
# La medición del voltímetro tardó 0.01680469512939453 segundos
# La medición del amperímetro tardó 0.016667604446411133 segundos
# La medición del sensor pirani tardó 0.29364848136901855 segundos
# La medición tomo un total de 0.3271207809448242 segundos
# La medición del voltímetro tardó 0.016204118728637695 segundos
# La medición del amperímetro tardó 0.017123937606811523 segundos
# La medición del sensor pirani tardó 0.283158540725708 segundos
# La medición tomo un total de 0.3164865970611572 segundos
# La medición del voltímetro tardó 0.022780418395996094 segundos
# La medición del amperímetro tardó 0.010455846786499023 segundos
# La medición del sensor pirani tardó 0.29077792167663574 segundos
# La medición tomo un total de 0.32401418685913086 segundos
# La medición del voltímetro tardó 0.01673102378845215 segundos
# La medición del amperímetro tardó 0.016136884689331055 segundos
# La medición del sensor pirani tardó 0.2841207981109619 segundos
# La medición tomo un total de 0.3169887065887451 segundos
# La medición del voltímetro tardó 0.0166933536529541 segundos
# La medición del amperímetro tardó 0.01920628547668457 segundos
# La medición del sensor pirani tardó 0.2811148166656494 segundos
# La medición tomo un total de 0.3170144557952881 segundos
# La medición del voltímetro tardó 0.01669001579284668 segundos
# La medición del amperímetro tardó 0.0198972225189209 segundos
# La medición del sensor pirani tardó 0.29041171073913574 segundos
# La medición tomo un total de 0.3269989490509033 segundos
# La medición del voltímetro tardó 0.016314029693603516 segundos
# La medición del amperímetro tardó 0.010244131088256836 segundos
# La medición del sensor pirani tardó 0.29050540924072266 segundos
# La medición tomo un total de 0.317063570022583 segundos
# La medición del voltímetro tardó 0.020617961883544922 segundos
# La medición del amperímetro tardó 0.012265682220458984 segundos
# La medición del sensor pirani tardó 0.2905402183532715 segundos
# La medición tomo un total de 0.3234238624572754 segundos
# La medición del voltímetro tardó 0.017403602600097656 segundos
# La medición del amperímetro tardó 0.012390851974487305 segundos
# La medición del sensor pirani tardó 0.28724193572998047 segundos
# La medición tomo un total de 0.31703639030456543 segundos
# La medición del voltímetro tardó 0.020017385482788086 segundos
# La medición del amperímetro tardó 0.01338958740234375 segundos
# La medición del sensor pirani tardó 0.28359389305114746 segundos
# La medición tomo un total de 0.3170008659362793 segundos
# La medición del voltímetro tardó 0.020061254501342773 segundos
# La medición del amperímetro tardó 0.013342618942260742 segundos
# La medición del sensor pirani tardó 0.2835707664489746 segundos
# La medición tomo un total de 0.3169746398925781 segundos
# La medición del voltímetro tardó 0.020082712173461914 segundos
# La medición del amperímetro tardó 0.013370990753173828 segundos
# La medición del sensor pirani tardó 0.29639649391174316 segundos
# La medición tomo un total de 0.3298501968383789 segundos
# La medición del voltímetro tardó 0.013969182968139648 segundos
# La medición del amperímetro tardó 0.01621866226196289 segundos
# La medición del sensor pirani tardó 0.2872657775878906 segundos
# La medición tomo un total de 0.31745362281799316 segundos
# La medición del voltímetro tardó 0.01669931411743164 segundos
# La medición del amperímetro tardó 0.010558605194091797 segundos
# La medición del sensor pirani tardó 0.29183340072631836 segundos
# La medición tomo un total de 0.3190913200378418 segundos
# La medición del voltímetro tardó 0.015137195587158203 segundos
# La medición del amperímetro tardó 0.01660609245300293 segundos
# La medición del sensor pirani tardó 0.28368568420410156 segundos
# La medición tomo un total de 0.3154289722442627 segundos
# La medición del voltímetro tardó 0.0166928768157959 segundos
# La medición del amperímetro tardó 0.01662445068359375 segundos
# La medición del sensor pirani tardó 0.28365159034729004 segundos
# La medición tomo un total de 0.3169689178466797 segundos
# La medición del voltímetro tardó 0.016725540161132812 segundos
# La medición del amperímetro tardó 0.016617298126220703 segundos
# La medición del sensor pirani tardó 0.2937347888946533 segundos
# La medición tomo un total de 0.32707762718200684 segundos
# La medición del voltímetro tardó 0.016256332397460938 segundos
# La medición del amperímetro tardó 0.007045745849609375 segundos
# La medición del sensor pirani tardó 0.29332947731018066 segundos
# La medición tomo un total de 0.316631555557251 segundos
# La medición del voltímetro tardó 0.02200627326965332 segundos
# La medición del amperímetro tardó 0.011663675308227539 segundos
# La medición del sensor pirani tardó 0.29021668434143066 segundos
# La medición tomo un total de 0.3238866329193115 segundos
# La medición del voltímetro tardó 0.016689777374267578 segundos
# La medición del amperímetro tardó 0.010096549987792969 segundos
# La medición del sensor pirani tardó 0.2901906967163086 segundos
# La medición tomo un total de 0.31697702407836914 segundos
# La medición del voltímetro tardó 0.01670384407043457 segundos
# La medición del amperímetro tardó 0.016820192337036133 segundos
# La medición del sensor pirani tardó 0.2834947109222412 segundos
# La medición tomo un total de 0.3170187473297119 segundos
# La medición del voltímetro tardó 0.016639232635498047 segundos
# La medición del amperímetro tardó 0.016784191131591797 segundos
# La medición del sensor pirani tardó 0.29357051849365234 segundos
# La medición tomo un total de 0.3269939422607422 segundos
# La medición del voltímetro tardó 0.01630425453186035 segundos
# La medición del amperímetro tardó 0.01024484634399414 segundos
# La medición del sensor pirani tardó 0.2904837131500244 segundos
# La medición tomo un total de 0.3170328140258789 segundos
# La medición del voltímetro tardó 0.016695737838745117 segundos
# La medición del amperímetro tardó 0.009876728057861328 segundos
# La medición del sensor pirani tardó 0.29646730422973633 segundos
# La medición tomo un total de 0.3230397701263428 segundos
# La medición del voltímetro tardó 0.01677703857421875 segundos
# La medición del amperímetro tardó 0.01062631607055664 segundos
# La medición del sensor pirani tardó 0.29017066955566406 segundos
# La medición tomo un total de 0.31757402420043945 segundos
# La medición del voltímetro tardó 0.016681671142578125 segundos
# La medición del amperímetro tardó 0.016649961471557617 segundos
# La medición del sensor pirani tardó 0.28354334831237793 segundos
# La medición tomo un total de 0.31687498092651367 segundos
# La medición del voltímetro tardó 0.0167391300201416 segundos
# La medición del amperímetro tardó 0.01666569709777832 segundos
# La medición del sensor pirani tardó 0.28359532356262207 segundos
# La medición tomo un total de 0.317000150680542 segundos
# La medición del voltímetro tardó 0.016724109649658203 segundos
# La medición del amperímetro tardó 0.0167233943939209 segundos
# La medición del sensor pirani tardó 0.2936387062072754 segundos
# La medición tomo un total de 0.3270862102508545 segundos
# La medición del voltímetro tardó 0.016231536865234375 segundos
# La medición del amperímetro tardó 0.0169522762298584 segundos
# La medición del sensor pirani tardó 0.2833225727081299 segundos
# La medición tomo un total de 0.31650638580322266 segundos
# La medición del voltímetro tardó 0.021475553512573242 segundos
# La medición del amperímetro tardó 0.011855363845825195 segundos
# La medición del sensor pirani tardó 0.2907090187072754 segundos
# La medición tomo un total de 0.32403993606567383 segundos
# La medición del voltímetro tardó 0.01674365997314453 segundos
# La medición del amperímetro tardó 0.01613593101501465 segundos
# La medición del sensor pirani tardó 0.2840547561645508 segundos
# La medición tomo un total de 0.31693434715270996 segundos
# La medición del voltímetro tardó 0.016729116439819336 segundos
# La medición del amperímetro tardó 0.018270492553710938 segundos
# La medición del sensor pirani tardó 0.28199267387390137 segundos
# La medición tomo un total de 0.31699228286743164 segundos
# La medición del voltímetro tardó 0.02008342742919922 segundos
# La medición del amperímetro tardó 0.013463020324707031 segundos
# La medición del sensor pirani tardó 0.29405951499938965 segundos
# La medición tomo un total de 0.3276059627532959 segundos
# La medición del voltímetro tardó 0.009442567825317383 segundos
# La medición del amperímetro tardó 0.013343334197998047 segundos
# La medición del sensor pirani tardó 0.29366612434387207 segundos
# La medición tomo un total de 0.3164520263671875 segundos
# La medición del voltímetro tardó 0.01926898956298828 segundos
# La medición del amperímetro tardó 0.01365804672241211 segundos
# La medición del sensor pirani tardó 0.2902350425720215 segundos
# La medición tomo un total de 0.3231620788574219 segundos
# La medición del voltímetro tardó 0.016098737716674805 segundos
# La medición del amperímetro tardó 0.009600639343261719 segundos
# La medición del sensor pirani tardó 0.29407286643981934 segundos
# La medición tomo un total de 0.31977224349975586 segundos
# La medición del voltímetro tardó 0.013405799865722656 segundos
# La medición del amperímetro tardó 0.016635656356811523 segundos
# La medición del sensor pirani tardó 0.28358936309814453 segundos
# La medición tomo un total de 0.3136308193206787 segundos
# La medición del voltímetro tardó 0.016759634017944336 segundos
# La medición del amperímetro tardó 0.016604900360107422 segundos
# La medición del sensor pirani tardó 0.28356075286865234 segundos
# La medición tomo un total de 0.3169252872467041 segundos
# La medición del voltímetro tardó 0.026313304901123047 segundos
# La medición del amperímetro tardó 0.007108211517333984 segundos
# La medición del sensor pirani tardó 0.29373645782470703 segundos
# La medición tomo un total de 0.32715797424316406 segundos
# La medición del voltímetro tardó 0.01621079444885254 segundos
# La medición del amperímetro tardó 0.01672673225402832 segundos
# La medición del sensor pirani tardó 0.2840301990509033 segundos
# La medición tomo un total de 0.3169677257537842 segundos
# La medición del voltímetro tardó 0.01662445068359375 segundos
# La medición del amperímetro tardó 0.01633286476135254 segundos
# La medición del sensor pirani tardó 0.29048609733581543 segundos
# La medición tomo un total de 0.3234434127807617 segundos
# La medición del voltímetro tardó 0.016742229461669922 segundos
# La medición del amperímetro tardó 0.016720056533813477 segundos
# La medición del sensor pirani tardó 0.28362298011779785 segundos
# La medición tomo un total de 0.31708526611328125 segundos
# La medición del voltímetro tardó 0.016677379608154297 segundos
# La medición del amperímetro tardó 0.01669478416442871 segundos
# La medición del sensor pirani tardó 0.28374552726745605 segundos
# La medición tomo un total de 0.31711769104003906 segundos
# La medición del voltímetro tardó 0.01662611961364746 segundos
# La medición del amperímetro tardó 0.016595125198364258 segundos
# La medición del sensor pirani tardó 0.2943706512451172 segundos
# La medición tomo un total de 0.3275918960571289 segundos
# La medición del voltímetro tardó 0.017585277557373047 segundos
# La medición del amperímetro tardó 0.00499725341796875 segundos
# La medición del sensor pirani tardó 0.29328179359436035 segundos
# La medición tomo un total de 0.31586432456970215 segundos
# La medición del voltímetro tardó 0.016656875610351562 segundos
# La medición del amperímetro tardó 0.016686677932739258 segundos
# La medición del sensor pirani tardó 0.29067015647888184 segundos
# La medición tomo un total de 0.32401371002197266 segundos
# La medición del voltímetro tardó 0.016714096069335938 segundos
# La medición del amperímetro tardó 0.009601116180419922 segundos
# La medición del sensor pirani tardó 0.29067182540893555 segundos
# La medición tomo un total de 0.3169870376586914 segundos
# La medición del voltímetro tardó 0.016732215881347656 segundos
# La medición del amperímetro tardó 0.018157243728637695 segundos
# La medición del sensor pirani tardó 0.2820432186126709 segundos
# La medición tomo un total de 0.31693267822265625 segundos
# La medición del voltímetro tardó 0.016710281372070312 segundos
# La medición del amperímetro tardó 0.01987767219543457 segundos
# La medición del sensor pirani tardó 0.2900509834289551 segundos
# La medición tomo un total de 0.32663893699645996 segundos
# La medición del voltímetro tardó 0.017017364501953125 segundos
# La medición del amperímetro tardó 0.009995460510253906 segundos
# La medición del sensor pirani tardó 0.2904813289642334 segundos
# La medición tomo un total de 0.31749415397644043 segundos
# La medición del voltímetro tardó 0.016661643981933594 segundos
# La medición del amperímetro tardó 0.009749174118041992 segundos
# La medición del sensor pirani tardó 0.2966427803039551 segundos
# La medición tomo un total de 0.32305359840393066 segundos
# La medición del voltímetro tardó 0.01672673225402832 segundos
# La medición del amperímetro tardó 0.0055081844329833984 segundos
# La medición del sensor pirani tardó 0.2977471351623535 segundos
# La medición tomo un total de 0.31998205184936523 segundos
# La medición del voltímetro tardó 0.014224767684936523 segundos
# La medición del amperímetro tardó 0.016646385192871094 segundos
# La medición del sensor pirani tardó 0.28346753120422363 segundos
# La medición tomo un total de 0.31433868408203125 segundos
# La medición del voltímetro tardó 0.020123958587646484 segundos
# La medición del amperímetro tardó 0.013336896896362305 segundos
# La medición del sensor pirani tardó 0.2868318557739258 segundos
# La medición tomo un total de 0.32029271125793457 segundos
# La medición del voltímetro tardó 0.01347041130065918 segundos
# La medición del amperímetro tardó 0.016717195510864258 segundos
# La medición del sensor pirani tardó 0.29369497299194336 segundos
# La medición tomo un total de 0.3238825798034668 segundos
# La medición del voltímetro tardó 0.009852886199951172 segundos
# La medición del amperímetro tardó 0.022986412048339844 segundos
# La medición del sensor pirani tardó 0.28673648834228516 segundos
# La medición tomo un total de 0.31957578659057617 segundos
# La medición del voltímetro tardó 0.013576030731201172 segundos
# La medición del amperímetro tardó 0.02026224136352539 segundos
# La medición del sensor pirani tardó 0.2882552146911621 segundos
# La medición tomo un total de 0.32209348678588867 segundos
# La medición del voltímetro tardó 0.015549421310424805 segundos
# La medición del amperímetro tardó 0.00960087776184082 segundos
# La medición del sensor pirani tardó 0.2906668186187744 segundos
# La medición tomo un total de 0.31581711769104004 segundos
# La medición del voltímetro tardó 0.01669454574584961 segundos
# La medición del amperímetro tardó 0.016707181930541992 segundos
# La medición del sensor pirani tardó 0.2836291790008545 segundos
# La medición tomo un total de 0.3170309066772461 segundos
# La medición del voltímetro tardó 0.016684770584106445 segundos
# La medición del amperímetro tardó 0.016635656356811523 segundos
# La medición del sensor pirani tardó 0.29367780685424805 segundos
# La medición tomo un total de 0.326998233795166 segundos
# La medición del voltímetro tardó 0.016724348068237305 segundos
# La medición del amperímetro tardó 0.006646394729614258 segundos
# La medición del sensor pirani tardó 0.29364514350891113 segundos
# La medición tomo un total de 0.3170158863067627 segundos
# La medición del voltímetro tardó 0.020437955856323242 segundos
# La medición del amperímetro tardó 0.014479398727416992 segundos
# La medición del sensor pirani tardó 0.2885007858276367 segundos
# La medición tomo un total de 0.32341814041137695 segundos
# La medición del voltímetro tardó 0.016788244247436523 segundos
# La medición del amperímetro tardó 0.009601354598999023 segundos
# La medición del sensor pirani tardó 0.290729284286499 segundos
# La medición tomo un total de 0.31711888313293457 segundos
# La medición del voltímetro tardó 0.01674628257751465 segundos
# La medición del amperímetro tardó 0.0172579288482666 segundos
# La medición del sensor pirani tardó 0.28302597999572754 segundos
# La medición tomo un total de 0.3170301914215088 segundos
# La medición del voltímetro tardó 0.016648054122924805 segundos
# La medición del amperímetro tardó 0.020067930221557617 segundos
# La medición del sensor pirani tardó 0.28015780448913574 segundos
# La medición tomo un total de 0.31687378883361816 segundos
# La medición del voltímetro tardó 0.020072460174560547 segundos
# La medición del amperímetro tardó 0.013441324234008789 segundos
# La medición del sensor pirani tardó 0.2868490219116211 segundos
# La medición tomo un total de 0.32036280632019043 segundos
# La medición del voltímetro tardó 0.02349543571472168 segundos
# La medición del amperímetro tardó 0.016216516494750977 segundos
# La medición del sensor pirani tardó 0.28686952590942383 segundos
# La medición tomo un total de 0.3265814781188965 segundos
# La medición del voltímetro tardó 0.020466327667236328 segundos
# La medición del amperímetro tardó 0.01015615463256836 segundos
# La medición del sensor pirani tardó 0.29012203216552734 segundos
# La medición tomo un total de 0.32074451446533203 segundos
# La medición del voltímetro tardó 0.016646623611450195 segundos
# La medición del amperímetro tardó 0.01671910285949707 segundos
# La medición del sensor pirani tardó 0.28360414505004883 segundos
# La medición tomo un total de 0.3169698715209961 segundos
# La medición del voltímetro tardó 0.016744613647460938 segundos
# La medición del amperímetro tardó 0.0166015625 segundos
# La medición del sensor pirani tardó 0.28368115425109863 segundos
# La medición tomo un total de 0.31702733039855957 segundos
# La medición del voltímetro tardó 0.016699552536010742 segundos
# La medición del amperímetro tardó 0.016659975051879883 segundos
# La medición del sensor pirani tardó 0.29328227043151855 segundos
# La medición tomo un total de 0.3266417980194092 segundos
# La medición del voltímetro tardó 0.017058134078979492 segundos
# La medición del amperímetro tardó 0.016318321228027344 segundos
# La medición del sensor pirani tardó 0.28354859352111816 segundos
# La medición tomo un total de 0.316925048828125 segundos
# La medición del voltímetro tardó 0.01711750030517578 segundos
# La medición del amperímetro tardó 0.01672077178955078 segundos
# La medición del sensor pirani tardó 0.29015660285949707 segundos
# La medición tomo un total de 0.32399487495422363 segundos
# La medición del voltímetro tardó 0.016623497009277344 segundos
# La medición del amperímetro tardó 0.016258716583251953 segundos
# La medición del sensor pirani tardó 0.2875957489013672 segundos
# La medición tomo un total de 0.3204779624938965 segundos
# La medición del voltímetro tardó 0.013281822204589844 segundos
# La medición del amperímetro tardó 0.016666650772094727 segundos
# La medición del sensor pirani tardó 0.2835221290588379 segundos
# La medición tomo un total de 0.31347060203552246 segundos
# La medición del voltímetro tardó 0.016675949096679688 segundos
# La medición del amperímetro tardó 0.016672134399414062 segundos
# La medición del sensor pirani tardó 0.2836270332336426 segundos
# La medición tomo un total de 0.31697511672973633 segundos
# La medición del voltímetro tardó 0.026790142059326172 segundos
# La medición del amperímetro tardó 0.006593227386474609 segundos
# La medición del sensor pirani tardó 0.29378652572631836 segundos
# La medición tomo un total de 0.32716989517211914 segundos
# La medición del voltímetro tardó 0.016219615936279297 segundos
# La medición del amperímetro tardó 0.010297536849975586 segundos
# La medición del sensor pirani tardó 0.29038000106811523 segundos
# La medición tomo un total de 0.3168971538543701 segundos
# La medición del voltímetro tardó 0.01673126220703125 segundos
# La medición del amperímetro tardó 0.013434410095214844 segundos
# La medición del sensor pirani tardó 0.2888815402984619 segundos
# La medición tomo un total de 0.319047212600708 segundos
# La medición del voltímetro tardó 0.01516580581665039 segundos
# La medición del amperímetro tardó 0.016732215881347656 segundos
# La medición del sensor pirani tardó 0.28659844398498535 segundos
# La medición tomo un total de 0.3184964656829834 segundos
# La medición del voltímetro tardó 0.013637781143188477 segundos
# La medición del amperímetro tardó 0.016666650772094727 segundos
# La medición del sensor pirani tardó 0.28359460830688477 segundos
# La medición tomo un total de 0.31389904022216797 segundos
# La medición del voltímetro tardó 0.01671433448791504 segundos
# La medición del amperímetro tardó 0.016666412353515625 segundos
# La medición del sensor pirani tardó 0.2937195301055908 segundos
# La medición tomo un total de 0.3271002769470215 segundos
# La medición del voltímetro tardó 0.01622486114501953 segundos
# La medición del amperímetro tardó 0.016681194305419922 segundos
# La medición del sensor pirani tardó 0.2841203212738037 segundos
# La medición tomo un total de 0.31702637672424316 segundos
# La medición del voltímetro tardó 0.021176815032958984 segundos
# La medición del amperímetro tardó 0.013929605484008789 segundos
# La medición del sensor pirani tardó 0.28852009773254395 segundos
# La medición tomo un total de 0.3236265182495117 segundos
# La medición del voltímetro tardó 0.016630172729492188 segundos
# La medición del amperímetro tardó 0.00960087776184082 segundos
# La medición del sensor pirani tardó 0.29066896438598633 segundos
# La medición tomo un total de 0.31690001487731934 segundos
# La medición del voltímetro tardó 0.01663994789123535 segundos
# La medición del amperímetro tardó 0.016741514205932617 segundos
# La medición del sensor pirani tardó 0.2835853099822998 segundos
# La medición tomo un total de 0.3169667720794678 segundos
# La medición del voltímetro tardó 0.016634225845336914 segundos
# La medición del amperímetro tardó 0.016715288162231445 segundos
# La medición del sensor pirani tardó 0.29371213912963867 segundos
# La medición tomo un total de 0.32706165313720703 segundos
# La medición del voltímetro tardó 0.01621866226196289 segundos
# La medición del amperímetro tardó 0.0071125030517578125 segundos
# La medición del sensor pirani tardó 0.29363465309143066 segundos
# La medición tomo un total de 0.31696581840515137 segundos
# La medición del voltímetro tardó 0.016247034072875977 segundos
# La medición del amperímetro tardó 0.01706528663635254 segundos
# La medición del sensor pirani tardó 0.2897930145263672 segundos
# La medición tomo un total de 0.3231053352355957 segundos
# La medición del voltímetro tardó 0.016656160354614258 segundos
# La medición del amperímetro tardó 0.010102987289428711 segundos
# La medición del sensor pirani tardó 0.2906761169433594 segundos
# La medición tomo un total de 0.31743526458740234 segundos
# La medición del voltímetro tardó 0.01663994789123535 segundos
# La medición del amperímetro tardó 0.017277240753173828 segundos
# La medición del sensor pirani tardó 0.2830514907836914 segundos
# La medición tomo un total de 0.3169686794281006 segundos
# La medición del voltímetro tardó 0.019965648651123047 segundos
# La medición del amperímetro tardó 0.013477087020874023 segundos
# La medición del sensor pirani tardó 0.2835204601287842 segundos
# La medición tomo un total de 0.31696319580078125 segundos
# La medición del voltímetro tardó 0.02004241943359375 segundos
# La medición del amperímetro tardó 0.013420581817626953 segundos
# La medición del sensor pirani tardó 0.28728437423706055 segundos
# La medición tomo un total de 0.32074737548828125 segundos
# La medición del voltímetro tardó 0.02267313003540039 segundos
# La medición del amperímetro tardó 0.016496658325195312 segundos
# La medición del sensor pirani tardó 0.2869868278503418 segundos
# La medición tomo un total de 0.3261566162109375 segundos
# La medición del voltímetro tardó 0.013454675674438477 segundos
# La medición del amperímetro tardó 0.01662611961364746 segundos
# La medición del sensor pirani tardó 0.29079246520996094 segundos
# La medición tomo un total de 0.3208732604980469 segundos
# La medición del voltímetro tardó 0.01659369468688965 segundos
# La medición del amperímetro tardó 0.009602546691894531 segundos
# La medición del sensor pirani tardó 0.290508508682251 segundos
# La medición tomo un total de 0.31670475006103516 segundos
# La medición del voltímetro tardó 0.016958236694335938 segundos
# La medición del amperímetro tardó 0.017064332962036133 segundos
# La medición del sensor pirani tardó 0.28646254539489746 segundos
# La medición tomo un total de 0.32048511505126953 segundos
# La medición del voltímetro tardó 0.01344919204711914 segundos
# La medición del amperímetro tardó 0.01660943031311035 segundos
# La medición del sensor pirani tardó 0.29368162155151367 segundos
# La medición tomo un total de 0.32374024391174316 segundos
# La medición del voltímetro tardó 0.01623678207397461 segundos
# La medición del amperímetro tardó 0.007081031799316406 segundos
# La medición del sensor pirani tardó 0.29319334030151367 segundos
# La medición tomo un total de 0.3165111541748047 segundos
# La medición del voltímetro tardó 0.01657891273498535 segundos
# La medición del amperímetro tardó 0.01674962043762207 segundos
# La medición del sensor pirani tardó 0.2906966209411621 segundos
# La medición tomo un total de 0.32402515411376953 segundos
# La medición del voltímetro tardó 0.016768932342529297 segundos
# La medición del amperímetro tardó 0.009644031524658203 segundos
# La medición del sensor pirani tardó 0.2905855178833008 segundos
# La medición tomo un total de 0.3169984817504883 segundos
# La medición del voltímetro tardó 0.016675472259521484 segundos
# La medición del amperímetro tardó 0.01674628257751465 segundos
# La medición del sensor pirani tardó 0.28356289863586426 segundos
# La medición tomo un total de 0.3169846534729004 segundos
# La medición del voltímetro tardó 0.016666412353515625 segundos
# La medición del amperímetro tardó 0.016737937927246094 segundos
# La medición del sensor pirani tardó 0.28351354598999023 segundos
# La medición tomo un total de 0.31691789627075195 segundos
# La medición del voltímetro tardó 0.02632927894592285 segundos
# La medición del amperímetro tardó 0.0071179866790771484 segundos
# La medición del sensor pirani tardó 0.2937202453613281 segundos
# La medición tomo un total de 0.3271675109863281 segundos
# La medición del voltímetro tardó 0.01669764518737793 segundos
# La medición del amperímetro tardó 0.0096588134765625 segundos
# La medición del sensor pirani tardó 0.29056787490844727 segundos
# La medición tomo un total de 0.3169243335723877 segundos
# La medición del voltímetro tardó 0.01934361457824707 segundos
# La medición del amperímetro tardó 0.013568401336669922 segundos
# La medición del sensor pirani tardó 0.2922375202178955 segundos
# La medición tomo un total de 0.3251495361328125 segundos
# La medición del voltímetro tardó 0.01710033416748047 segundos
# La medición del amperímetro tardó 0.014092206954956055 segundos
# La medición del sensor pirani tardó 0.28908681869506836 segundos
# La medición tomo un total de 0.3202793598175049 segundos
# La medición del voltímetro tardó 0.011853456497192383 segundos
# La medición del amperímetro tardó 0.016595840454101562 segundos
# La medición del sensor pirani tardó 0.28368520736694336 segundos
# La medición tomo un total de 0.3121345043182373 segundos
# La medición del voltímetro tardó 0.01677083969116211 segundos
# La medición del amperímetro tardó 0.01655125617980957 segundos
# La medición del sensor pirani tardó 0.29329657554626465 segundos
# La medición tomo un total de 0.32661867141723633 segundos
# La medición del voltímetro tardó 0.017113924026489258 segundos
# La medición del amperímetro tardó 0.006623983383178711 segundos
# La medición del sensor pirani tardó 0.29318857192993164 segundos
# La medición tomo un total de 0.3169264793395996 segundos

# %%
nro_medicion = 65
filename = rf'Clase 18-10\Medición nro {nro_medicion}.csv'
df = pd.read_csv(filename)
I = df['I'] #Corriente en celda
V = df['V'] #Tension en celda
#P = np.mean(df['P'].values)
#d = df['Distancia']
V_max = 460
#pd = P*d

fig,ax = plt.subplots(figsize = (15,7))

ax.scatter(np.log(I),np.log(V),color = 'cornflowerblue', s = 10)
#ax.scatter(pd,V_max)
# ylabels = np.linspace(min(V),max(V),26,endpoint = True)
# ylabels = np.linspace(0,1200,26,endpoint = True)
# ax.text(0.0010,200,f'Voltaje = {V_c} V')
# ax.text(0.001,100,f'Cant de puntos: {cant_mediciones}')
# ax.set_yticks(ylabels)
# ax.set_yticklabels([f'{number:.0f}' for number in ylabels]);
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# MEDICION CON GRAFICO EN VIVO

# %%
from IPython import display
# %matplotlib inline

nro_medicion = 15
T = [] #de aca sascamos para el V de la descarga en Volts
V_c = [] #de aca sale para la corriente en Volts
P = []
R2 = 55340
R1 = 67109000 #ohm
R3 = 14800
periodo = 10 #s
cant_mediciones = 150
tiempo_entre_medicion = 0.3 #seg/medicion
mediciones_para_un_periodo_y_medio = int(periodo//tiempo_entre_medicion)
V_gen = 1.600 #V

yticks = np.arange(0,11,10)*100

# for i in range(mediciones_para_un_periodo_y_medio), Donde 1 y 2 son la inicial y final para el promedio:
for i in range(cant_mediciones):
    print(f'Medicion numero: {i}')
    T_1 = float(volt.query("READ?"))
    V_1 = float(amperimetro.query("READ?"))
    T_2 = float(volt.query("READ?"))
    V_2 = float(amperimetro.query("READ?"))
    T_i = (T_1 + T_2)/2
    V_ci = (V_1 + V_2)/2
    P_i = float(pirani.query("?GA1"))
    P.append(P_i)
    T.append(T_i)
    V_c.append(V_ci)
    #pi.write("!US3")
    #print(pi.query("?GA1"))
    # print("i =", i)
    # print("T =", T_i)
    # print("V_c =", V_ci)
    I=[]#esta es la del tubo
    for j in range(len(T)):
        I.append(float(V_c[j])/R3)
    I_1=[] 
    for j in range(len(T)):
        I_1.append(float(T[j])/R2)
    #I_1=I*R2

    V=[]
    for j in range(len(V_c)):
        V.append(float(T[j])-float(V_c[j])+float(I_1[j])*R1)

    #plt.scatter(I,V)
    plt.xlabel("Corriente Celda")
    plt.ylabel("Tension Celda")
    # plt.yticks(ticks = yticks, labels = yticks)
    plt.scatter(I,V,color = 'cornflowerblue')
    display.display(plt.gcf())
    display.clear_output(wait=True)
    plt.pause(0.1)
   
    time.sleep(tiempo_entre_medicion)

df = pd.DataFrame()
df["T"] = T #Tension en R2
df['V'] = V #Tension en celda
df["V_c"] = V_c  #Tension en R3
df['I'] = I #Corriente en celda
df["P"] = P
df['V_gen'] = pd.Series(V_gen, index = [0])
df['Mediciones p/s'] = pd.Series(tiempo_entre_medicion,index = [0])
df['Fecha'] = pd.Series([time.ctime()],index = [0])
df['Periodo'] = pd.Series(periodo, index = [0])
df['Distancia'] = pd.Series('15.6',index = [0])
df.to_csv(f"C:/Users/publico/Desktop/G6L5V/Clase 18-10/Medición nro {nro_medicion}.csv", encoding = "utf-8")

# %%
volt.write('CONF:VOLT:DC 1,0.001')
# Out:
# 22

# %%
nro_medicion = 500
filename = rf'Clase 18-10\Medición nro 500.csv'
df = pd.read_csv(filename)
I = df['I'] #Corriente en celda
V = df['V'] #Tension en celda

fig,ax = plt.subplots(figsize = (12,7))

ax.plot(I[0:(int(len(I)/2)+30)],V[0:(int(len(I)/2)+30)],color = 'cornflowerblue',marker = '.')
# ax.plot(V,color = 'cornflowerblue')

ylabels = np.linspace(min(V),max(V),26,endpoint = True)
#ax.set_xlim(0.0015,0.0025)
# ylabels = np.linspace(0,1200,26,endpoint = True)
ax.set_yticks(ylabels)
ax.set_yticklabels([f'{number:.0f}' for number in ylabels]);
xlabels = np.linspace(min(I),max(I),26,endpoint = True)
#ax.set_xlim(0.0015,0.0025)
# ylabels = np.linspace(0,1200,26,endpoint = True)
ax.set_xticks(xlabels)
ax.set_xticklabels([f'{number:.3f}' for number in xlabels]);

# %%
for nro_medicion in [1,2,3,4,6,7,8,10,11]:
    filename = rf'Clase 18-10\Medición nro {nro_medicion}.csv'
    df = pd.read_csv(filename)
    I = df['I'] #Corriente en celda
    V = df['V'] #Tension en celda

    fig,ax = plt.subplots()

    ax.scatter(I,V,color = 'cornflowerblue')
    ylabels = np.linspace(min(V),max(V),26,endpoint = True)
    #ax.set_xlim(0.0015,0.0025)
    # ylabels = np.linspace(0,1200,26,endpoint = True)
    ax.set_yticks(ylabels)
    ax.set_yticklabels([f'{number:.0f}' for number in ylabels]);

# %%
print(type(presion[0]))
print(presion)
fig,ax = plt.subplots(figsize = (15,5))
ax.scatter(np.arange(len(presion)),presion, color = 'cornflowerblue',marker = '.')
# Out:
# <class 'float'>
# [1000.0, 1000.0, 1000.0, 1000.0, 1000.0, 482.0, 78.8, 25.7, 11.7, 5.96, 3.31, 2.07, 1.3, 0.911, 0.648, 0.503, 0.401, 0.343, 0.288, 0.262, 0.239, 0.223, 0.212, 0.202, 0.194, 0.187, 0.181, 0.177, 0.173, 0.17, 0.166, 0.164, 0.162, 0.16, 0.158, 0.156, 0.154, 0.152, 0.151, 0.15, 0.149, 0.147, 0.145, 0.144, 0.143, 0.142, 0.14, 0.139, 0.139, 0.137]

# %%
print(pirani.write('*IDN?'))
print(pirani.query("?GA2"))
# Out:
# 7
# 1.00E+03

# %%
T_i = float(volt.query("MEASURE:VOLTAGE:DC?"))
V_ci = float(amperimetro.query("MEASURE:VOLTAGE:DC?"))
